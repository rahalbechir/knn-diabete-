# %% [markdown]
# <a href="https://colab.research.google.com/github/rahalbechir/knn-diabete-/blob/main/data_visualisation_and_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd

# %%
path="/content/data_sales"
files = [file for file in os.listdir(path) if not file.startswith('.')]
all_months_data = pd.DataFrame()
for file in files:
  current_data = pd.read_csv(path+"/"+file)
  all_months_data = pd.concat([all_months_data, current_data])

all_months_data.to_csv("all_data_copy.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-38d62c33e089> in <cell line: 2>()
#       1 path="/content/data_sales"
# ----> 2 files = [file for file in os.listdir(path) if not file.startswith('.')]
#       3 all_months_data = pd.DataFrame()
#       4 for file in files:
#       5   current_data = pd.read_csv(path+"/"+file)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/data_sales'

# %%
my_data= pd.read_csv('/content/all_data_copy.csv')
my_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
#
#        Order Date                      Purchase Address
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016

# %%
my_data.shape
# Out:
# (186850, 6)

# %%
nan_df = my_data[my_data.isna().any(axis=1)]
display(nan_df.head())
nan_df.shape
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1047      NaN     NaN              NaN        NaN        NaN              NaN
# 1542      NaN     NaN              NaN        NaN        NaN              NaN
# 1653      NaN     NaN              NaN        NaN        NaN              NaN
# 2014      NaN     NaN              NaN        NaN        NaN              NaN
# 2043      NaN     NaN              NaN        NaN        NaN              NaN
# (545, 6)

# %%
x=my_data['Purchase Address'].str.split(',',expand=True).split()
x.head()
# Out:
#                0               1          2
# 0  942 Church St          Austin   TX 73301
# 1  942 Church St          Austin   TX 73301
# 2  942 Church St          Austin   TX 73301
# 3    261 10th St   San Francisco   CA 94016
# 4    764 13th St   San Francisco   CA 94016

# %%
y=x[1].head()
print(y)
# Out:
# 0            Austin
# 1            Austin
# 2            Austin
# 3     San Francisco
# 4     San Francisco
# Name: 1, dtype: object

# %%
my_data['city']=y

# %%
my_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
#
#        Order Date Purchase Address            city
# 0  03/28/19 20:59           Austin          Austin
# 1  03/28/19 20:59           Austin          Austin
# 2  03/28/19 20:59           Austin          Austin
# 3  03/17/19 05:39    San Francisco   San Francisco
# 4  03/10/19 00:01    San Francisco   San Francisco
